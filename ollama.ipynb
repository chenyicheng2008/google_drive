# %% [markdown]
# <a href="https://colab.research.google.com/github/chenyicheng2008/google_drive/blob/main/ollama.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
apikey_ollam='6afb7604323e49b499631fe16e02c388.VQ7czOp3yqAKsw8m9uJcAFX1'

# %%
#google drive load
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
# 指定在 Google Drive 上的安裝路徑
drive_path = '/content/drive/MyDrive/Colab_packages'
# !pip install ollama --target=$drive_path
# Out:
# Collecting ollama
#   Downloading ollama-0.6.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting httpx>=0.27 (from ollama)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting pydantic>=2.9 (from ollama)
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 3.6 MB/s eta 0:00:00
# Collecting anyio (from httpx>=0.27->ollama)
#   Downloading anyio-4.12.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting certifi (from httpx>=0.27->ollama)
#   Downloading certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx>=0.27->ollama)
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx>=0.27->ollama)
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx>=0.27->ollama)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.9->ollama)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic>=2.9->ollama)
#   Downloading pydantic_core-2.41.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Collecting typing-extensions>=4.14.1 (from pydantic>=2.9->ollama)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic>=2.9->ollama)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Downloading ollama-0.6.1-py3-none-any.whl (14 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 7.4 MB/s eta 0:00:00
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 8.1 MB/s eta 0:00:00
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 463.6/463.6 kB 16.9 MB/s eta 0:00:00
# Downloading pydantic_core-2.41.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 55.9 MB/s eta 0:00:00
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 3.5 MB/s eta 0:00:00
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading anyio-4.12.0-py3-none-any.whl (113 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.4/113.4 kB 11.1 MB/s eta 0:00:00
# Downloading idna-3.11-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.0/71.0 kB 6.5 MB/s eta 0:00:00
# Downloading certifi-2025.11.12-py3-none-any.whl (159 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.4/159.4 kB 14.7 MB/s eta 0:00:00
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Installing collected packages: typing-extensions, idna, h11, certifi, annotated-types, typing-inspection, pydantic-core, httpcore, anyio, pydantic, httpx, ollama
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gradio 5.50.0 requires pydantic<=2.12.3,>=2.0, but you have pydantic 2.12.5 which is incompatible.
# Successfully installed annotated-types-0.7.0 anyio-4.12.0 certifi-2025.11.12 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.11 ollama-0.6.1 pydantic-2.12.5 pydantic-core-2.41.5 typing-extensions-4.15.0 typing-inspection-0.4.2

# %%
import sys
# 確保 Drive 已掛載

# 將安裝路徑加入系統路徑，這樣 Python 才能找到 yfinance
sys.path.insert(0, '/content/drive/My Drive/colab_packages')

# %%
DOC_ID_gmail = '1Q861W26L2Z6hIcIqVIi7NDkev22uJn1_NdNI_sY-vuw'
gmail_txt = r'/content/drive/MyDrive/LINE_mail_backup2008Gmail/EmailBackup.txt'
Line_txt = r'/content/drive/MyDrive/LINE_mail_backup2008Gmail/LineBackup.txt'

DOC_ID_line = "1VhKPn9kZ2RYVZfQckV4AIaMB3xS_gd14TQU1K-fPol4"

# %%
#read DOC_ID_gmail_dir
with open(gmail_txt, 'r') as f:
    gmail_file = f.read()
with open(Line_txt, 'r') as f:
    line_file = f.read()

# %%
# !ollama pull gpt-oss:120b-cloud
# !ollama signin
# Out:
# /bin/bash: line 1: ollama: command not found
# /bin/bash: line 1: ollama: command not found

# %%
from google.colab import auth
from googleapiclient.discovery import build

# Authenticate to Google Colab
auth.authenticate_user()

# Initialize the Google Docs service client
docs_service = build('docs', 'v1')

print("Google Colab authenticated and Docs service initialized.")
# Out:
# Google Colab authenticated and Docs service initialized.

# %%
print(f"apikey_ollam: {apikey_ollam}")
# Out:
# apikey_ollam: 6afb7604323e49b499631fe16e02c388.VQ7czOp3yqAKsw8m9uJcAFX1

# %% [markdown]
# # Task
# Combine the content of `gmail_file` and `line_file` and truncate the combined string to 200,000 characters to prevent 'prompt too long' errors. Then, use this truncated content to generate a summary of '近3日重大個股及產業訊息及新聞,及未來一個月會議排程' via the Ollama API, displaying the summary or any error messages if the API call fails.

# %% [markdown]
# ## Combine and Truncate Document Content
#
# ### Subtask:
# Combine the content of `gmail_file` and `line_file` into a single string. To avoid 'prompt too long' errors, the combined content will be truncated to a manageable length (e.g., 200,000 characters).

# %% [markdown]
# **Reasoning**:
# The subtask requires combining `gmail_file` and `line_file` and then truncating the result to 200,000 characters to create `combined_document_content_truncated` to avoid 'prompt too long' errors.

# %%
pip install tiktoken
# Out:
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.12/dist-packages (0.12.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken) (2025.11.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from tiktoken) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken) (2025.11.12)

# %%
import tiktoken

def count_tokens(text, model_name="gpt-4"):
    """Counts the number of tokens in a text using tiktoken."""
    encoding = tiktoken.encoding_for_model(model_name)
    tokens = encoding.encode(text)
    return len(tokens)

# Assuming gmail_file and line_file are already loaded from previous cells
gmail_tokens = count_tokens(gmail_file)
line_tokens = count_tokens(line_file)

print(f"Gmail file token count: {gmail_tokens}")
print(f"Line file token count: {line_tokens}")
# Out:
# Gmail file token count: 63153
# Line file token count: 51066

# %% [markdown]
# ## Construct Summarization Prompt
#
# ### Subtask:
# Create a detailed prompt for the Ollama model, instructing it to summarize '近3日重大個股及產業訊息及新聞,及未來一個月會議排程' from the truncated combined document content.

# %% [markdown]
# **Reasoning**:
# To construct the detailed prompt for the Ollama model as instructed, I will define the `overall_messages` variable with the specified structure, combining the summarization request and the truncated document content.

# %%
combined_document_content = gmail_file + line_file
#combined_document_content_truncated = combined_document_content[:200000]
overall_messages = [
    {
        'role': 'user',
        'content': "Summarize '近5日股票市場個股及產業訊息及新聞,及今日及未來一個月會議排程, 列示舉辦單位及地點' from the following content: " + combined_document_content,
    },
]

print("Prompt created successfully.")
# Out:
# Prompt created successfully.

# %%
import os
from ollama import Client, ResponseError
import requests # Added for robust error handling potential within the try-except

model_to_use = 'gpt-oss:120b-cloud'
model_to_use = 'qwen3-vl:235b'


try:
    # Initialize Ollama client with host and authorization header
    client = Client(
        host='https://ollama.com',
        headers={'Authorization': 'Bearer ' + apikey_ollam}
    )

    full_summary = ""
    print(f"Calling Ollama API with model: {model_to_use}...")
    for part in client.chat(model=model_to_use, messages=overall_messages, stream=True):
        content = part.get('message', {}).get('content', '')
        if content:
            full_summary += content
            print(content, end='', flush=True)
    print("\n--- Summary Complete ---")
    print(full_summary)
    full_summary =f"Calling Ollama API with model: {model_to_use}..."+full_summary
    #write fullsummary to " r'/content/drive/MyDrive/LINE_mail_backup2008Gmail/fullsummary_ollam.txt'"
    with open(r'/content/drive/MyDrive/LINE_mail_backup2008Gmail/fullsummary_ollam.txt', 'w') as f:
        f.write(full_summary)
        print("fullsummary_ollam.txt written successfully.")

except ResponseError as e:
    if e.status_code == 401:
        print(f"Error: 401 Unauthorized. Please check your Ollama Cloud API endpoint ('https://ollama.com') and your API key ('{apikey_ollam}').")
    else:
        print(f"An Ollama API error occurred: Status Code {e.status_code} - {e.message}")
except requests.exceptions.RequestException as e:
    print(f"A network or request error occurred: {e}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Calling Ollama API with model: qwen3-vl:235b...
# # 近5日股票市場個股及產業訊息及新聞摘要
#
# ## 市場整體動態
# - 美國財政問題與通膨擔憂引發10~30年期美債殖利率攀升，形成熊陡(Bear Steepening)曲線
# - AI題材降溫，博通財報未能釋疑，導致科技、半導體類股重挫拉回，上週五美股指數全面下挫
# - 台股雖有聯發科、智邦等權值股逆勢上漲，仍不敵台積電為首的多數權值下跌拖累
# - 加權指數失守28,000點整數關卡，但整體格局仍堅守月線(MA20)之上，長天期均線維持多頭排列
#
# ## 重點產業/個股動向
# - 12/18(四) 14:00：8930青鋼線上法說（線上）
# - 12/18(四) 14:00：8341日友參訪（地點未明確）
# - 12/18(四) 14:30：9934成霖法說會（地點未明確）
# - 12/19(五) 14:00：4137麗豐-KY法說會（地點未明確）
# - 12/22(一) 10:30：4541晟田webex會議（線上）
# - 12/23(二) 10:30：網通IC-推薦個股:聯發科/瑞昱webex會議（線上）
# - 12/24(三) 14:30：6154順發線上法說（線上）
# - 12/24(三) 14:00：1514亞力參訪（地點未明確）
# - 12/29(一) 14:00：2308台達電座談（地點未明確）
# - 12/30(二) 14:00：2474可成webex會議（線上）
# - 12/17(三) 14:00：LINE Pay Vision Day 2025法說會（地點未明確）
#
# ## 舉辦單位：元大證券
# - 12/15(一) 14:00：2457飛宏線上法說（線上）
# - 12/11(四) 14:30：4906正文法說會（線上）
# - 12/18(四) 14:00：1909榮成與1906寶隆國際線上聯合法人說明會（線上）
# - 12/19(五) 14:00：9951皇田線上法人說明會（線上）
# - 12/22(一) 14:30：2646星宇航空法人說明會（元大金融廣場3樓A廳，台北市仁愛路三段157號）
# - 1/5(一) 14:30：7871安立璽榮-KY興櫃前法人說明會（台北君悅酒店3樓凱悅廳一區，台北市信義區松壽路2號）
#
# ## 舉辦單位：凱基證券
# - 12/15(一) 14:30：4433興采線上法人說明會（線上）
# - 12/16(二) 14:30：6674鋐寶線上法人說明會（線上）
# - 12/17(三) 14:30：6516勤崴國際線上法人說明會（線上）
# - 12/18(四) 14:30：2634漢翔法人說明會（地點未明確）
# - 12/18(四) 14:30：5516雙喜線上法人說明會（線上）
# - 12/18(四) 14:30：2102南港線上法人說明會（線上）
# - 12/18(四) 14:30：6123上奇線上法人說明會（線上）
#
# ## 舉辦單位：統一證券
# - 12/22(一) 14:00：2642宅配通法說會（地點未明確）
# fullsummary_ollam.txt written successfully.

# %%
import os
from ollama import Client, ResponseError
import requests # Added for robust error handling potential within the try-except

model_to_use = 'gpt-oss:120b-cloud'
model_to_use = 'qwen3-vl:235b'


try:
    # Initialize Ollama client with host and authorization header
    client = Client(
        host='https://ollama.com',
        headers={'Authorization': 'Bearer ' + apikey_ollam}
    )

    full_summary = ""
    print(f"Calling Ollama API with model: {model_to_use}...")
    for part in client.chat(model=model_to_use, messages=overall_messages, stream=True):
        content = part.get('message', {}).get('content', '')
        if content:
            full_summary += content
            print(content, end='', flush=True)
    print("\n--- Summary Complete ---")
    print(full_summary)
    full_summary =f"Calling Ollama API with model: {model_to_use}..."+full_summary
    #write fullsummary to " r'/content/drive/MyDrive/LINE_mail_backup2008Gmail/fullsummary_ollam.txt'"
     ''
except ResponseError as e:
    if e.status_code == 401:
        print(f"Error: 401 Unauthorized. Please check your Ollama Cloud API endpoint ('https://ollama.com') and your API key ('{apikey_ollam}').")
    else:
        print(f"An Ollama API error occurred: Status Code {e.status_code} - {e.message}")
except requests.exceptions.RequestException as e:
    print(f"A network or request error occurred: {e}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
